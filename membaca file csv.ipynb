# %%
import pandas as pd

# %% [markdown]
# CSV

# %%
file_path = r"D:\Personal\Learning\Jupyter Project\sample.csv" #simpan file

# %%
df = pd.read_csv(file_path) #membaca file

# %%
print(df.head())
# Out:
#       Tanggal  Produk  Jumlah     Harga     Total
# 0  2025-01-01  Laptop       2  15000000  30000000
# 1  2025-01-02      HP       5   3000000  15000000
# 2  2025-01-03  Tablet       3   5000000  15000000
# 3  2025-01-04  Laptop       1  16000000  16000000
# 4  2025-01-05      HP       4   2800000  11200000

# %%
print(df.shape) #ukuran dataset
# Out:
# (10, 5)

# %%
print(df.info()) #ringkasan data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tanggal  10 non-null     object
#  1   Produk   10 non-null     object
#  2   Jumlah   10 non-null     int64
#  3   Harga    10 non-null     int64
#  4   Total    10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes
# None

# %%
print(df.columns) #nama columns
# Out:
# Index(['Tanggal', 'Produk', 'Jumlah', 'Harga', 'Total'], dtype='object')

# %%
df = pd.read_csv(file_path, nrows = 10) #ingin mengambbil 10 column

# %%
print(df)
# Out:
#       Tanggal  Produk  Jumlah     Harga     Total
# 0  2025-01-01  Laptop       2  15000000  30000000
# 1  2025-01-02      HP       5   3000000  15000000
# 2  2025-01-03  Tablet       3   5000000  15000000
# 3  2025-01-04  Laptop       1  16000000  16000000
# 4  2025-01-05      HP       4   2800000  11200000
# 5  2025-01-06  Tablet       2   5200000  10400000
# 6  2025-01-07  Laptop       3  15500000  46500000
# 7  2025-01-08      HP       6   3100000  18600000
# 8  2025-01-09  Tablet       2   5100000  10200000
# 9  2025-01-10  Laptop       1  16500000  16500000
