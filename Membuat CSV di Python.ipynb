# %%
import pandas as pd

# %%
data = {
    "Nama": ["Andi", "Budi", "Citra", "Dewi"],
    "Umur": [23, 25, 22, 24],
    "Kota": ["Jakarta", "Bandung", "Surabaya", "Medan"]
}

# %%
df = pd.DataFrame(data)

# %%
df.to_csv("data_siswa.csv", index=False)

# %%
print("File CSV berhasil dibuat: data_siswa.csv")
# Out:
# File CSV berhasil dibuat: data_siswa.csv

# %%
df = pd.read_csv(r"D:\Personal\Learning\Jupyter Project\sample.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tanggal  10 non-null     object
#  1   Produk   10 non-null     object
#  2   Jumlah   10 non-null     int64
#  3   Harga    10 non-null     int64
#  4   Total    10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes

# %%
df.head()
# Out:
#       Tanggal  Produk  Jumlah     Harga     Total
# 0  2025-01-01  Laptop       2  15000000  30000000
# 1  2025-01-02      HP       5   3000000  15000000
# 2  2025-01-03  Tablet       3   5000000  15000000
# 3  2025-01-04  Laptop       1  16000000  16000000
# 4  2025-01-05      HP       4   2800000  11200000
